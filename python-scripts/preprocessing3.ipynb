# %%
import kagglehub
import pandas as pd
import os

# %%
dataset_path = kagglehub.dataset_download("raedaddala/top-500-600-movies-of-each-year-from-1960-to-2024")

csv_filename = os.path.join(dataset_path, "final_dataset.csv")
df = pd.read_csv(csv_filename)

print("Loaded dataset from:", csv_filename)
print(df.head())
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.9), please consider upgrading to the latest version (0.3.13).
# Loaded dataset from: C:\Users\rohan\.cache\kagglehub\datasets\raedaddala\top-500-600-movies-of-each-year-from-1960-to-2024\versions\9\final_dataset.csv
#           id                       title duration        mpa  rating votes  \
# 0  tt0027483          The Crimson Circle   1h 16m        NaN     6.4    30
# 1  tt0058131  The Mystery of Thug Island   1h 36m        NaN     5.0   114
# 2  tt0042760   Las mujeres de mi general   1h 52m  Not Rated     6.8    74
# 3  tt0027667                Gentle Julia    1h 2m   Approved     6.8    38
# 4  tt0055747              Love at Twenty   1h 50m        NaN     7.2  2.5K
#
#    méta_score                                        description  \
# 0         NaN  An extortion ring murders anyone who refuses t...
# 1         NaN  Three year old Ada, daughter of the British ca...
# 2         NaN  Infante stars as a rebel general caught up in ...
# 3         NaN  A shy newspaperman (Brown) nearly gives up whe...
# 4         NaN  "Love at Twenty" unites five directors from ar...
#
#                               movie_link  \
# 0  https://www.imdb.com/title/tt0027483/
# 1  https://www.imdb.com/title/tt0058131/
# 2  https://www.imdb.com/title/tt0042760/
# 3  https://www.imdb.com/title/tt0027667/
# 4  https://www.imdb.com/title/tt0055747/
#
#                                              writers  ...  \
# 0  ['Reginald Denham', 'Edgar Wallace', 'Howard I...  ...
# 1  ['Emilio Salgari', 'Arpad DeRiso', 'Ottavio Po...  ...
# 2  ['Joselito Rodríguez', 'Celestino Gorostiza', ...  ...
# 3               ['Booth Tarkington', 'Lamar Trotti']  ...
# 4  ['Shintarô Ishihara', 'Marcel Ophüls', 'Renzo ...  ...
#
#   opening_weekend_gross gross_worldwide gross_us_canada release_date  \
# 0                   NaN             NaN             NaN   1936-08-10
# 1                   NaN             NaN             NaN   1966-05-28
# 2                   NaN             NaN             NaN   1951-07-13
# 3                   NaN             NaN             NaN   1936-04-10
# 4                   NaN             NaN             NaN   1963-02-06
#
#                                     countries_origin  \
# 0                                 ['United Kingdom']
# 1                ['Italy', 'Monaco', 'West Germany']
# 2                                         ['Mexico']
# 3                                  ['United States']
# 4  ['France', 'Italy', 'Japan', 'Poland', 'West G...
#
#                                    filming_locations  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  ['20th Century Fox Studios - 10201 Pico Blvd.,...
# 4  ['Warsaw Zoo, Ratuszowa, Praga Pólnoc, Warsaw,...
#
#                                 production_companies awards_content  \
# 0                 ['Richard Wainwright Productions']            NaN
# 1                    ['Eichberg-Film', 'Liber Film']            NaN
# 2                ['Producciones Rodríguez Hermanos']            NaN
# 3                          ['Twentieth Century Fox']            NaN
# 4  ['Ulysse Productions', 'Unitec Films', 'Cinese...            NaN
#
#                            genres  \
# 0                       ['Drama']
# 1                   ['Adventure']
# 2                ['Drama', 'War']
# 3  ['Comedy', 'Drama', 'Romance']
# 4            ['Drama', 'Romance']
#
#                                            languages
# 0                                        ['English']
# 1                                        ['Italian']
# 2                                        ['Spanish']
# 3                                        ['English']
# 4  ['French', 'Polish', 'Japanese', 'Italian', 'G...
#
# [5 rows x 23 columns]

# %%
def convert_duration_to_minutes(duration):
    if pd.isna(duration):
        return 0  
    if isinstance(duration, int):
        return duration  

    total_minutes = 0
    parts = duration.split()
    for part in parts:
        if 'h' in part:
            total_minutes += int(part[:-1]) * 60 
        elif 'm' in part:
            total_minutes += int(part[:-1])  
    return total_minutes

df['duration'] = df['duration'].apply(convert_duration_to_minutes)

# %%
for col in df.columns:
    if df[col].dtype in ['int', 'int64', 'float64']: 
        df[col].fillna(0, inplace=True)
    else:
        df[col].fillna('', inplace=True)
# Out:
# C:\Users\rohan\AppData\Local\Temp\ipykernel_5392\1653071518.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna('', inplace=True)
# C:\Users\rohan\AppData\Local\Temp\ipykernel_5392\1653071518.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(0, inplace=True)

# %%
import ast
import pandas as pd

# %%
def parse_list(cell):
    if pd.isnull(cell) or cell == "":
        return []
    
    # Handle numeric values (int, float)
    if isinstance(cell, (int, float)):
        return [str(cell)]
    
    # Handle string values
    if isinstance(cell, str):
        try:
            return ast.literal_eval(cell)  
        except (ValueError, SyntaxError):
            return cell.split(", ")
    
    # Handle any other type
    return [str(cell)]

# %%
import re
import ast

def get_cleaned_name_string(name_list):
    cleaned_names = []
    if isinstance(name_list, str):
        if name_list != "":
            name_list = ast.literal_eval(name_list)
    if not isinstance(name_list, list):
        name_list = []
    for name in name_list:
        cleaned_name = re.sub(r'[^a-zA-Z]', '', name).lower()
        cleaned_names.append(cleaned_name)
    return ' '.join(cleaned_names)

# %%
def get_cleaned_locations(locations):
    cleaned_locations = []
    if isinstance(locations, str):
        if locations != "":
            locations = ast.literal_eval(locations)
    if not isinstance(locations, list):
        locations = []
    for location in locations:
        cleaned_location = desc_cleaning(location)
        cleaned_locations.append(cleaned_location)
    return ' '.join(cleaned_locations)

# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import TreebankWordTokenizer

# %%
stop_words = set(stopwords.words('english'))
tokenizer = TreebankWordTokenizer()

# %%
def name_cleaning(name):
    name = (name or "").lower()
    words = tokenizer.tokenize(name)
    filtered_words = [w for w in words if w not in stop_words]
    return " ".join(filtered_words)

def desc_cleaning(desc):
    desc = (desc or "").lower()
    desc = re.sub(r"[^a-z\s]", "", desc)
    words = tokenizer.tokenize(desc)
    filtered_words = [w for w in words if w not in stop_words]
    return " ".join(filtered_words)

def get_cleaned_doc(row):
    new_name = name_cleaning(row["title"])
    new_desc = desc_cleaning(row["description"])
    new_stars = get_cleaned_name_string(row["stars"])
    new_directors = get_cleaned_name_string(row["directors"])
    new_genres = get_cleaned_locations(row["genres"])
    new_production = get_cleaned_locations(row["production_companies"])
    new_filming_locations = get_cleaned_locations(row["filming_locations"])
    new_language = get_cleaned_name_string(row["languages"])
    new_countries = get_cleaned_name_string(row["countries_origin"])
    doc_list = [
        new_name,
        new_desc,
        new_stars,
        new_directors,
        new_genres,
        new_production,
        new_filming_locations,
        new_language,
        new_countries,
    ]
    return " ".join(doc_list)

# %%
# --- Build movie_data_dict safely ---
movie_data_dict = {}

# First iteration to store cleaned document data
for _, row in df.iterrows():
    movie_id = row["id"]
    movie_data_dict[movie_id] = {
        "docs": get_cleaned_doc(row)
    }

# %%
def ensure_year_column(df):
    """
    Ensures the DataFrame has a 'year' column.
    If missing, it extracts the year from 'release_date'.
    If 'release_date' is missing or invalid, fills with 0.
    """
    if 'year' not in df.columns:
        # Extract year from release_date (format YYYY-MM-DD)
        df['year'] = df.get('release_date', '').astype(str).str.extract(r'(\d{4})')
        # Convert to integer, fill NaN with 0
        df['year'] = df['year'].fillna(0).astype(int)
    return df

# Usage:
df = ensure_year_column(df)

# %%
for index, row in df.iterrows():
    print(row)
    break  # remove break to see all rows
# Out:
# id                                                               tt0027483
# title                                                   The Crimson Circle
# duration                                                                76
# mpa
# rating                                                                 6.4
# votes                                                                   30
# méta_score                                                             0.0
# description              An extortion ring murders anyone who refuses t...
# movie_link                           https://www.imdb.com/title/tt0027483/
# writers                  ['Reginald Denham', 'Edgar Wallace', 'Howard I...
# directors                                              ['Reginald Denham']
# stars                    ['Hugh Wakefield', 'Alfred Drayton', 'Niall Ma...
# budget
# opening_weekend_gross
# gross_worldwide
# gross_us_canada
# release_date                                                    1936-08-10
# countries_origin                                        ['United Kingdom']
# filming_locations
# production_companies                    ['Richard Wainwright Productions']
# awards_content                                                         0.0
# genres                                                           ['Drama']
# languages                                                      ['English']
# year                                                                  1936
# Name: 0, dtype: object

# %%
# Second iteration to add other movie data
for _, row in df.iterrows():
    movie_id = row["id"]
    if movie_id in movie_data_dict:
        movie_data_dict[movie_id].update({
            "title": row["title"],
            "year": row["year"],
            "duration": row["duration"],
            "MPA": row["mpa"],
            "rating": row["rating"],
            "votes": row["votes"],
            "meta_score": row["méta_score"],
            "description": row["description"],
            "Movie_Link": row["movie_link"],
            "writers": parse_list(row["writers"]),
            "directors": parse_list(row["directors"]),
            "stars": parse_list(row["stars"]),
            "budget": row["budget"],
            "opening_weekend_gross": row["opening_weekend_gross"],
            "gross_worldwide": row["gross_worldwide"],
            "gross_us_canada": row["gross_us_canada"],
            "release_date": row["release_date"],
            "countries_origin": parse_list(row["countries_origin"]),
            "filming_locations": parse_list(row["filming_locations"]),
            "production_companies": parse_list(row["production_companies"]),
            "awards_content": parse_list(row["awards_content"]),
            "genres": parse_list(row["genres"]),
            "languages": parse_list(row["languages"])
        })

# Print first 5 movie IDs and their data
first_5_keys = list(movie_data_dict.keys())[:5]
for key in first_5_keys:
    print(f"Movie ID: {key}, Data: {movie_data_dict[key]}")
# Out:
# Movie ID: tt0027483, Data: {'docs': 'crimson circle extortion ring murders anyone refuses pay protection money new scotland yard case victim killed protection sexy secretary falls suspicion bodies pile hughwakefield alfreddrayton niallmacginnis juneduprez paulblake noahbeery basilgill gordonmcleod reneegadd ralphtruman reginalddenham drama richard wainwright productions  english unitedkingdom', 'title': 'The Crimson Circle', 'year': 1936, 'duration': 76, 'MPA': '', 'rating': 6.4, 'votes': '30', 'meta_score': 0.0, 'description': 'An extortion ring murders anyone who refuses to pay protection money. New Scotland Yard is on the case, but a victim is killed while under their protection. A sexy secretary falls under suspicion as the bodies pile up.', 'Movie_Link': 'https://www.imdb.com/title/tt0027483/', 'writers': ['Reginald Denham', 'Edgar Wallace', 'Howard Irving Young'], 'directors': ['Reginald Denham'], 'stars': ['Hugh Wakefield', 'Alfred Drayton', 'Niall MacGinnis', 'June Duprez', 'Paul Blake', 'Noah Beery', 'Basil Gill', 'Gordon McLeod', 'Renee Gadd', 'Ralph Truman'], 'budget': '', 'opening_weekend_gross': '', 'gross_worldwide': '', 'gross_us_canada': '', 'release_date': '1936-08-10', 'countries_origin': ['United Kingdom'], 'filming_locations': [], 'production_companies': ['Richard Wainwright Productions'], 'awards_content': ['0.0'], 'genres': ['Drama'], 'languages': ['English']}
# Movie ID: tt0058131, Data: {'docs': 'mystery thug island three year old ada daughter british captain mcpherson captured indian tukh sect represent incarnation kali ever hidden vast underground system caverns watches human sacrifices doubting vocation years passed father finally finds attempts rescue together snakehunter fallen love battle ensues guymadison ingeborgschner giacomorossistuart ivandesny giuliarubini ferdinandopoggi petervaneyck aldobufilandi aldocristiani romanogiomini luigicapuano adventure eichbergfilm liber film  italian italy monaco westgermany', 'title': 'The Mystery of Thug Island', 'year': 1966, 'duration': 96, 'MPA': '', 'rating': 5.0, 'votes': '114', 'meta_score': 0.0, 'description': 'Three year old Ada, daughter of the British captain McPherson, is captured by the Indian Tukh sect to represent the incarnation of Kali. Ever hidden in a vast underground system of caverns, she watches over human sacrifices, doubting her vocation. 15 years have passed when her father finally finds her and attempts a rescue, together with a snake-hunter who has fallen in love with her. A battle ensues.', 'Movie_Link': 'https://www.imdb.com/title/tt0058131/', 'writers': ['Emilio Salgari', 'Arpad DeRiso', 'Ottavio Poggi'], 'directors': ['Luigi Capuano'], 'stars': ['Guy Madison', 'Ingeborg Schöner', 'Giacomo Rossi Stuart', 'Ivan Desny', 'Giulia Rubini', 'Ferdinando Poggi', 'Peter van Eyck', 'Aldo Bufi Landi', 'Aldo Cristiani', 'Romano Giomini'], 'budget': '', 'opening_weekend_gross': '', 'gross_worldwide': '', 'gross_us_canada': '', 'release_date': '1966-05-28', 'countries_origin': ['Italy', 'Monaco', 'West Germany'], 'filming_locations': [], 'production_companies': ['Eichberg-Film', 'Liber Film'], 'awards_content': ['0.0'], 'genres': ['Adventure'], 'languages': ['Italian']}
# Movie ID: tt0042760, Data: {'docs': 'las mujeres de mi general infante stars rebel general caught tempestuous romantic tugofwar two women exgirlfriend chula prieto wife lilia prado love triangle yields devastating consequences must face governmental soldiers revolution pedroinfante liliaprado chulaprieto miguelmanzano miguelincln arturosotorangel lupeincln albertocatal miguelngellpez pedrodeurdimalas ismaelrodrguez drama war producciones rodrguez hermanos  spanish mexico', 'title': 'Las mujeres de mi general', 'year': 1951, 'duration': 112, 'MPA': 'Not Rated', 'rating': 6.8, 'votes': '74', 'meta_score': 0.0, 'description': 'Infante stars as a rebel general caught up in a tempestuous romantic tug-of-war between two women: ex-girlfriend (Chula Prieto) and wife (Lilia Prado). This love triangle yields devastating consequences as they must face the governmental soldiers during the revolution.', 'Movie_Link': 'https://www.imdb.com/title/tt0042760/', 'writers': ['Joselito Rodríguez', 'Celestino Gorostiza', 'Ismael Rodríguez'], 'directors': ['Ismael Rodríguez'], 'stars': ['Pedro Infante', 'Lilia Prado', 'Chula Prieto', 'Miguel Manzano', 'Miguel Inclán', 'Arturo Soto Rangel', 'Lupe Inclán', 'Alberto Catalá', 'Miguel Ángel López', 'Pedro de Urdimalas'], 'budget': '', 'opening_weekend_gross': '', 'gross_worldwide': '', 'gross_us_canada': '', 'release_date': '1951-07-13', 'countries_origin': ['Mexico'], 'filming_locations': [], 'production_companies': ['Producciones Rodríguez Hermanos'], 'awards_content': ['0.0'], 'genres': ['Drama', 'War'], 'languages': ['Spanish']}
# Movie ID: tt0027667, Data: {'docs': 'gentle julia shy newspaperman brown nearly gives girlfriend hunt falls new guy town meeker till withers sets things right janewithers tombrown marshahunt jackiesearl francisford georgemeeker mauricemurphy harryholman myramarsh hattiemcdaniel johngblystone comedy drama romance twentieth century fox th century fox studios pico blvd century city los angeles california usa studio english unitedstates', 'title': 'Gentle Julia', 'year': 1936, 'duration': 62, 'MPA': 'Approved', 'rating': 6.8, 'votes': '38', 'meta_score': 0.0, 'description': 'A shy newspaperman (Brown) nearly gives up when his girlfriend (Hunt) falls for the new guy in town (Meeker) till Withers sets things right.', 'Movie_Link': 'https://www.imdb.com/title/tt0027667/', 'writers': ['Booth Tarkington', 'Lamar Trotti'], 'directors': ['John G. Blystone'], 'stars': ['Jane Withers', 'Tom Brown', 'Marsha Hunt', 'Jackie Searl', 'Francis Ford', 'George Meeker', 'Maurice Murphy', 'Harry Holman', 'Myra Marsh', 'Hattie McDaniel'], 'budget': '', 'opening_weekend_gross': '', 'gross_worldwide': '', 'gross_us_canada': '', 'release_date': '1936-04-10', 'countries_origin': ['United States'], 'filming_locations': ['20th Century Fox Studios - 10201 Pico Blvd., Century City, Los Angeles, California, USA (Studio)'], 'production_companies': ['Twentieth Century Fox'], 'awards_content': ['0.0'], 'genres': ['Comedy', 'Drama', 'Romance'], 'languages': ['English']}
# Movie ID: tt0055747, Data: {'docs': 'love twenty love twenty unites five directors around world present different perspectives love really age episodes united score georges delerue still photos henri cartierbresson directors create peculiar scenarios truffaut revisiting antoine doinel time finding meaning life getting involved girl renzo rossellinis episode abandoned mistress ishiharas tale obsessive love ophls story pregnant woman trying plot babys father wajda presenting confusing relationship people different generations jeanpierrelaud mariefrancepisier patrickauffay rosyvarte franoisdarbon jeanfranoisadam pierreschaeffer cristinagaioni geronimomeynier eleonorarossidrago shintarishihara marcelophls renzorossellini drama romance ulysse productions unitec films cinesecolo warsaw zoo ratuszowa praga plnoc warsaw mazowieckie poland segment warsaw french polish japanese italian german france italy japan poland westgermany', 'title': 'Love at Twenty', 'year': 1963, 'duration': 110, 'MPA': '', 'rating': 7.2, 'votes': '2.5K', 'meta_score': 0.0, 'description': '"Love at Twenty" unites five directors from around the world to present their different perspectives on what love really is at the age of 20. The episodes are united with the score of Georges Delerue and still photos of Henri Cartier-Bresson. The directors create their peculiar scenarios with Truffaut revisiting Antoine Doinel, this time finding some meaning to his life while getting involved with a girl; Renzo Rossellini\'s episode about an abandoned mistress; Ishihara\'s tale about an obsessive love; Ophüls\' story about a pregnant woman trying to plot against the baby\'s father; and Wajda presenting a confusing relationship between people from different generations.', 'Movie_Link': 'https://www.imdb.com/title/tt0055747/', 'writers': ['Shintarô Ishihara', 'Marcel Ophüls', 'Renzo Rossellini'], 'directors': ['Shintarô Ishihara', 'Marcel Ophüls', 'Renzo Rossellini'], 'stars': ['Jean-Pierre Léaud', 'Marie-France Pisier', 'Patrick Auffay', 'Rosy Varte', 'François Darbon', 'Jean-François Adam', 'Pierre Schaeffer', 'Cristina Gaioni', 'Geronimo Meynier', 'Eleonora Rossi Drago'], 'budget': '', 'opening_weekend_gross': '', 'gross_worldwide': '', 'gross_us_canada': '', 'release_date': '1963-02-06', 'countries_origin': ['France', 'Italy', 'Japan', 'Poland', 'West Germany'], 'filming_locations': ['Warsaw Zoo, Ratuszowa, Praga Pólnoc, Warsaw, Mazowieckie, Poland (segment "Warsaw")'], 'production_companies': ['Ulysse Productions', 'Unitec Films', 'Cinesecolo'], 'awards_content': ['0.0'], 'genres': ['Drama', 'Romance'], 'languages': ['French', 'Polish', 'Japanese', 'Italian', 'German']}

# %%
df_cleaned = pd.DataFrame.from_dict(movie_data_dict, orient="index")
df_cleaned.to_csv("./../cleaned_database/cleaned_final_dataset3.csv", index_label="id")
print("Dictionary saved to ./../cleaned_database/cleaned_final_dataset3.csv")
# Out:
# Dictionary saved to ./../cleaned_database/cleaned_final_dataset3.csv
